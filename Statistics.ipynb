# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
rng1 = np.random.RandomState(0)
rng2 = np.random.RandomState(5)
x = rng1.randint(10, size=20)
x
# Out:
# array([5, 0, 3, 3, 7, 9, 3, 5, 2, 4, 7, 6, 8, 8, 1, 6, 7, 7, 8, 1])

# %%
n = len(x)
x_mean = sum(x)/n
x_mean
# Out:
# 5.0

# %%
np.mean(x)
# Out:
# 5.0

# %%
q= np.median(x)
w=np.sort(x)
c= np.median(w)
print(x)
print(q)
print(w)
print(c)
np.var(x)
# Out:
# [5 0 3 3 7 9 3 5 2 4 7 6 8 8 1 6 7 7 8 1]
# 5.5
# [0 1 1 2 3 3 3 4 5 5 6 6 7 7 7 7 8 8 8 9]
# 5.5
# 7.0

# %%
np.std(x)
# Out:
# 2.6457513110645907

# %%
y = rng2.randint(10, size=20)

# %%
np.cov(x,y)
# Out:
# array([[ 7.36842105,  2.21052632],
#        [ 2.21052632, 10.09210526]])

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.25634071],
#        [0.25634071, 1.        ]])

# %%
plt.scatter(x,y)
z = np.polyfit(x,y,1)
p = np.poly1d(z)
plt.plot(x, p(x), 'r-o')

# %%
x1 = rng1.randint(100, size=500)
y1 = rng2.randint(100, size=500)

# %%
np.corrcoef(x1,y1)
# Out:
# array([[ 1.       , -0.0573669],
#        [-0.0573669,  1.       ]])

# %%
plt.scatter(x1,y1)
z1 = np.polyfit(x1,y1,1)
p1 = np.poly1d(z1)
plt.plot(x1,p(x1),'r-o')

# %%
air_quality = pd.read_csv("../c4_epa_air_quality.csv")

# %%
air_quality.head(10)
# Out:
#    Unnamed: 0  date_local    state_name   county_name      city_name  \
# 0           0  2018-01-01       Arizona      Maricopa        Buckeye
# 1           1  2018-01-01          Ohio       Belmont      Shadyside
# 2           2  2018-01-01       Wyoming         Teton  Not in a city
# 3           3  2018-01-01  Pennsylvania  Philadelphia   Philadelphia
# 4           4  2018-01-01          Iowa          Polk     Des Moines
# 5           5  2018-01-01        Hawaii      Honolulu  Not in a city
# 6           6  2018-01-01        Hawaii      Honolulu  Not in a city
# 7           7  2018-01-01  Pennsylvania          Erie           Erie
# 8           8  2018-01-01        Hawaii      Honolulu       Honolulu
# 9           9  2018-01-01      Colorado       Larimer   Fort Collins
#
#                                      local_site_name   parameter_name  \
# 0                                            BUCKEYE  Carbon monoxide
# ...

# %%
air_quality.tail(5)
# Out:
#      Unnamed: 0  date_local            state_name           county_name  \
# 255         255  2018-01-01  District Of Columbia  District of Columbia
# 256         256  2018-01-01             Wisconsin                 Dodge
# 257         257  2018-01-01              Kentucky             Jefferson
# 258         258  2018-01-01              Nebraska               Douglas
# 259         259  2018-01-01        North Carolina                  Wake
#
#          city_name        local_site_name   parameter_name   units_of_measure  \
# 255     Washington              Near Road  Carbon monoxide  Parts per million
# 256       Kekoskee  HORICON WILDLIFE AREA  Carbon monoxide  Parts per million
# 257     Louisville           CANNONS LANE  Carbon monoxide  Parts per million
# 258          Omaha                    NaN  Carbon monoxide  Parts per million
# 259  Not in a city             Triple Oak  Carbon monoxide  Parts per million
#
#      arithmetic_mean  aqi
# 255         0.244444    3
# ...

# %%
air_quality.columns.all
# Out:
# <bound method Index.all of Index(['Unnamed: 0', 'date_local', 'state_name', 'county_name', 'city_name',
#        'local_site_name', 'parameter_name', 'units_of_measure',
#        'arithmetic_mean', 'aqi'],
#       dtype='object')>

# %%
air_quality.describe()
# Out:
#        Unnamed: 0  arithmetic_mean         aqi
# count  260.000000       260.000000  260.000000
# mean   129.500000         0.403169    6.757692
# std     75.199734         0.317902    7.061707
# min      0.000000         0.000000    0.000000
# 25%     64.750000         0.200000    2.000000
# 50%    129.500000         0.276315    5.000000
# 75%    194.250000         0.516009    9.000000
# max    259.000000         1.921053   50.000000

# %%
air_quality.count()
# Out:
# Unnamed: 0          260
# date_local          260
# state_name          260
# county_name         260
# city_name           260
# local_site_name     257
# parameter_name      260
# units_of_measure    260
# arithmetic_mean     260
# aqi                 260
# dtype: int64

# %%
air_quality['state_name'].describe()
# Out:
# count            260
# unique            52
# top       California
# freq              66
# Name: state_name, dtype: object

# %%
np.mean(air_quality['aqi'])
# Out:
# 6.757692307692308

# %%
np.median(air_quality['aqi'])
# Out:
# 5.0

# %%
np.min(air_quality['aqi'])
# Out:
# 0

# %%
np.max(air_quality['aqi'])
# Out:
# 50

# %%
st_a = np.std(air_quality['aqi'])
st_a
# Out:
# 7.048113390607722

# %%
st_a **2
# Out:
# 49.67590236686388

# %% [markdown]
# # Sampling and Main formulations

# %%
pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.api as sn
from scipy import stats

# %%
air_quality.head(5)
# Out:
#    Unnamed: 0  date_local    state_name   county_name      city_name  \
# 0           0  2018-01-01       Arizona      Maricopa        Buckeye
# 1           1  2018-01-01          Ohio       Belmont      Shadyside
# 2           2  2018-01-01       Wyoming         Teton  Not in a city
# 3           3  2018-01-01  Pennsylvania  Philadelphia   Philadelphia
# 4           4  2018-01-01          Iowa          Polk     Des Moines
#
#                                      local_site_name   parameter_name  \
# 0                                            BUCKEYE  Carbon monoxide
# 1                                          Shadyside  Carbon monoxide
# 2  Yellowstone National Park - Old Faithful Snow ...  Carbon monoxide
# 3                             North East Waste (NEW)  Carbon monoxide
# 4                                          CARPENTER  Carbon monoxide
#
#     units_of_measure  arithmetic_mean  aqi
# 0  Parts per million         0.473684    7
# ...

# %%
air_quality.info() # null and non null values and datatypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        260 non-null    int64
#  1   date_local        260 non-null    object
#  2   state_name        260 non-null    object
#  3   county_name       260 non-null    object
#  4   city_name         260 non-null    object
#  5   local_site_name   257 non-null    object
#  6   parameter_name    260 non-null    object
#  7   units_of_measure  260 non-null    object
#  8   arithmetic_mean   260 non-null    float64
#  9   aqi               260 non-null    int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 20.4+ KB

# %%
air_quality.columns #heading
# Out:
# Index(['Unnamed: 0', 'date_local', 'state_name', 'county_name', 'city_name',
#        'local_site_name', 'parameter_name', 'units_of_measure',
#        'arithmetic_mean', 'aqi'],
#       dtype='object')

# %%
air_quality.size
# Out:
# 2600

# %%
air_quality.shape
# Out:
# (260, 10)

# %%
air_quality.index
# Out:
# RangeIndex(start=0, stop=260, step=1)

# %%
air_quality.describe()
# Out:
#        Unnamed: 0  arithmetic_mean         aqi
# count  260.000000       260.000000  260.000000
# mean   129.500000         0.403169    6.757692
# std     75.199734         0.317902    7.061707
# min      0.000000         0.000000    0.000000
# 25%     64.750000         0.200000    2.000000
# 50%    129.500000         0.276315    5.000000
# 75%    194.250000         0.516009    9.000000
# max    259.000000         1.921053   50.000000

# %%
sample_air = air_quality.sample(n=50, replace = True, random_state=42)

# %%
sample_air.head(5)
# Out:
#      Unnamed: 0  date_local  state_name county_name   city_name  \
# 102         102  2018-01-01       Texas      Harris     Houston
# 106         106  2018-01-01  California    Imperial    Calexico
# 71           71  2018-01-01     Alabama   Jefferson  Birmingham
# 188         188  2018-01-01     Arizona    Maricopa       Tempe
# 20           20  2018-01-01    Virginia     Roanoke      Vinton
#
#                    local_site_name   parameter_name   units_of_measure  \
# 102                        Clinton  Carbon monoxide  Parts per million
# 106          Calexico-Ethel Street  Carbon monoxide  Parts per million
# 71           Arkadelphia/Near Road  Carbon monoxide  Parts per million
# 188                         Diablo  Carbon monoxide  Parts per million
# 20   East Vinton Elementary School  Carbon monoxide  Parts per million
#
#      arithmetic_mean  aqi
# 102         0.157895    2
# 106         1.183333   26
# 71          0.200000    2
# 188         0.542105   10
# ...

# %%
air_quality['aqi'].hist()
# Out:
# <Axes: >

# %%
est_list = []
for i in range(10):
    est_list.append(air_quality['aqi'].sample(n=50, replace=True).mean())

# %%
est_df = pd.DataFrame(data={'estimate': est_list})
est_df
# Out:
#    estimate
# 0      7.46
# 1      5.18
# 2      9.26
# 3      6.02
# 4      6.16
# 5      6.02
# 6      5.74
# 7      7.54
# 8      6.74
# 9      7.88

# %%
est_df.hist()
# Out:
# array([[<Axes: title={'center': 'estimate'}>]], dtype=object)

# %%
mair_quality = pd.read_csv('../modified_c4_epa_air_quality.csv')

# %%
mair_quality['z_score'] = stats.zscore(mair_quality['aqi_log'])
mair_quality[(mair_quality['z_score'] > 3) | (mair_quality['z_score'] < -3)]
# Out:
#      date_local state_name county_name city_name local_site_name  \
# 244  2018-01-01    Arizona    Maricopa   Phoenix    WEST PHOENIX
#
#       parameter_name   units_of_measure   aqi_log   z_score
# 244  Carbon monoxide  Parts per million  3.931826  3.034886
